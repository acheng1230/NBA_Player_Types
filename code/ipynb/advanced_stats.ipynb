# %%
# Load packages
import re
import pandas as pd
import numpy as np

np.set_printoptions(suppress=True)

# %%
test = pd.read_csv('/Users/alexcheng/Desktop/test_file.csv')
test.head()
# Out:
#    Rk                  Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   1  Alex Abrines\abrinal01  SG   23  OKC  46   643   9.9  0.566  0.716
# 1   2      Quincy Acy\acyqu01  PF   26  TOT  18   182  15.8  0.617  0.462
# 2   2      Quincy Acy\acyqu01  PF   26  DAL   6    48  -1.4  0.355  0.412
# 3   2      Quincy Acy\acyqu01  PF   26  BRK  12   134  21.9  0.703  0.479
# 4   3  Steven Adams\adamsst01   C   23  OKC  55  1695  17.0  0.600  0.004
#
#    ...   Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM   BPM  \
# 0  ...           NaN  0.7  0.5  1.2  0.091          NaN  -0.6  -2.5  -3.1
# 1  ...           NaN  0.3  0.1  0.4  0.118          NaN  -0.8  -3.1  -4.0
# 2  ...           NaN -0.2  0.0 -0.1 -0.133          NaN -10.1  -6.1 -16.2
# 3  ...           NaN  0.5  0.1  0.6  0.208          NaN   2.5  -2.1   0.4
# 4  ...           NaN  2.5  2.2  4.7  0.133          NaN  -0.7   1.2   0.5
#
#    VORP
# 0  -0.2
# 1  -0.1
# 2  -0.2
# 3   0.1
# 4   1.1
#
# ...

# %%
test.columns
# Out:
# Index([u'Rk', u'Player', u'Pos', u'Age', u'Tm', u'G', u'MP', u'PER', u'TS%',
#        u'3PAr', u'FTr', u'ORB%', u'DRB%', u'TRB%', u'AST%', u'STL%', u'BLK%',
#        u'TOV%', u'USG%', u'Unnamed: 19', u'OWS', u'DWS', u'WS', u'WS/48',
#        u'Unnamed: 24', u'OBPM', u'DBPM', u'BPM', u'VORP'],
#       dtype='object')

# %%
test.drop(['Rk', 'Tm', 'MP', 'Unnamed: 19', 'Unnamed: 24', 'PER'], axis=1, inplace=True)

# %%
regex_list = []
name_list = []

player_list = list(test['Player'])

for player_id in player_list:
    this_regex = re.findall('\\\(\w+)', player_id)[0]
    regex_list.append(this_regex)
    this_name = re.findall('\w.+\s\w+', player_id)[0]
    name_list.append(this_name)

test['Player_ID'] = regex_list
test['Player'] = name_list

# %%
test
# Out:
#                     Player Pos  Age   G    TS%   3PAr    FTr  ORB%  DRB%  \
# 0             Alex Abrines  SG   23  46  0.566  0.716  0.204   2.1   6.7
# 1               Quincy Acy  PF   26  18  0.617  0.462  0.308   7.7  15.5
# 2               Quincy Acy  PF   26   6  0.355  0.412  0.176   4.6  15.4
# 3               Quincy Acy  PF   26  12  0.703  0.479  0.354   8.8  15.6
# 4             Steven Adams   C   23  55  0.600  0.004  0.369  12.6  15.9
# 5            Arron Afflalo  SG   31  49  0.548  0.386  0.216   0.8   7.8
# 6            Alexis Ajinca   C   28  23  0.497  0.031  0.247   7.7  23.7
# 7             Cole Aldrich   C   28  51  0.553  0.000  0.284  11.4  24.3
# 8        LaMarcus Aldridge  PF   31  51  0.541  0.052  0.305   8.4  17.1
# 9              Lavoy Allen  PF   27  42  0.462  0.009  0.187   9.9  12.8
# 10              Tony Allen  SG   35  49  0.489  0.074  0.251   9.3  13.8
# 11         Al-Farouq Aminu  SF   26  37  0.476  0.466  0.228   4.3  24.0
# ...

# %%
test.shape
# Out:
# (487, 24)

# %%
groupby = test.groupby([test.Player, test.Pos, test.Player_ID]).mean()

# %%
groupby.to_csv('/Users/alexcheng/Desktop/groupby.csv')

# %%
# !pwd
# Out:
# /Users/alexcheng/dsi/dsi_workspace/projects/project-captsone/workspace/web_scraping/ipynb
