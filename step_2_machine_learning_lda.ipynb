# %% [markdown]
# ### Import Packages

# %%
# Import packages
import re
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Sci-Kit Learn
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# Import module
from lib.cluster import kmeans, find_best_cluster, feature_importance, plot_kmeans_cluster
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ### Import Data

# %%
file_loc = "data/stats_14-17.csv"

# %%
data = pd.read_csv(file_loc)
data
# Out:
#      Unnamed: 0    Status               Player Pos  Player_ID  \
# 0             0  Inactive           A.J. Price  PG  priceaj01
# 1             1    Active         Aaron Brooks  PG  brookaa01
# 2             2    Active         Aaron Gordon  SF  gordoaa01
# 3             3    Active       Aaron Harrison  SG  harriaa01
# 4             4    Active        Adreian Payne  PF  paynead01
# 5             5    Active           Al Horford   C  horfoal01
# 6             6    Active         Al Jefferson   C  jeffeal01
# 7             7    Active      Al-Farouq Aminu  SF  aminual01
# 8             8    Active        Alan Anderson  SF  anderal01
# 9             9    Active        Alan Williams  PF  willial03
# 10           10    Active           Alec Burks  SG  burksal01
# 11           11    Active         Alex Abrines  SG  abrinal01
# 12           12  Inactive            Alex Kirk   C   kirkal01
# 13           13    Active             Alex Len   C    lenal01
# 14           14  Inactive       Alex Stepheson  PF  stephal01
# 15           15  Inactive         Alexey Shved  SG  shvedal01
# 16           16    Active        Alexis Ajinca   C  ajincal01
# 17           17    Active         Allen Crabbe  SG  crabbal01
# 18           18    Active           Alonzo Gee  SF    geeal01
# 19           19  Inactive    Amar'e Stoudemire   C  stoudam01
# 20           20    Active         Amir Johnson  PF  johnsam01
# 21           21    Active     Anderson Varejao   C  varejan01
# 22           22  Inactive        Andre Dawkins  SG  dawkian01
# 23           23    Active       Andre Drummond   C  drumman01
# 24           24    Active       Andre Iguodala  SF  iguodan01
# 25           25  Inactive         Andre Miller  PG  millean02
# 26           26    Active       Andre Roberson  SF  roberan03
# 27           27  Inactive      Andrea Bargnani   C  bargnan01
# 28           28  Inactive     Andrei Kirilenko  SF  kirilan01
# 29           29    Active         Andrew Bogut   C  bogutan01
# ..          ...       ...                  ...  ..        ...
# 634         634    Active         Tyler Zeller   C  zellety01
# 635         635    Active         Tyreke Evans  SG  evansty01
# 636         636  Inactive         Tyrus Thomas  PF  thomaty01
# 637         637    Active       Tyson Chandler   C  chandty01
# 638         638    Active           Tyus Jones  PG  jonesty01
# 639         639    Active        Udonis Haslem   C  hasleud01
# 640         640  Inactive          Vander Blue  SG   blueva01
# 641         641  Inactive        Victor Claver  SF  clavevi01
# 642         642    Active       Victor Oladipo  SG  oladivi01
# 643         643    Active         Vince Carter  SG  cartevi01
# 644         644    Active         Wade Baldwin  PG  baldwwa01
# 645         645    Active       Walter Tavares   C  tavarwa01
# 646         646    Active      Wayne Ellington  SG  ellinwa01
# 647         647    Active       Wesley Johnson  SF  johnswe01
# 648         648    Active      Wesley Matthews  SG  matthwe02
# 649         649    Active          Will Barton  SG  bartowi01
# 650         650  Inactive           Will Bynum  SG  bynumwi01
# 651         651  Inactive          Will Cherry  PG  cherrwi01
# 652         652    Active  Willie Cauley-Stein   C  caulewi01
# 653         653  Inactive         Willie Green  SG  greenwi01
# 654         654    Active          Willie Reed   C   reedwi02
# 655         655    Active    Willy Hernangomez   C  hernawi01
# 656         656    Active      Wilson Chandler  SF  chandwi01
# 3       5.5      8.7    73   104
# 4       7.2     15.1    87   110
# 5       3.7     22.3   114   104
# 6       4.6     28.3   108   105
# 7       4.1     15.5   101   106
# 8       4.6     18.6   103   110
# 9      10.9     21.1   107   101
# 10      4.6     24.3   104   110
# 11      5.3     18.9   112   111
# 12      3.7     14.9   112   115
# 13      7.0     16.8   101   106
# 14      8.4     15.4   101   107
# 15      3.1     21.1    99   108
# 16      8.8     20.3   104   106
# 17      4.4     18.0   112   111
# 18      4.5     15.6   102   109
# 19      5.2     31.0   113   105
# 20      7.2     17.4   117   105
# 21      5.7     15.9   114   102
# 22      7.2      7.2    53   113
# 23      5.3     23.0   109   100
# 24      2.8     19.3   110   105
# 25      3.7     21.1   110   108
# 26      4.8     10.2   109   105
# 27      4.4     26.0   103   111
# 28      3.6     20.9   112   103
# 29      5.6     17.8   107   102
# ..      ...      ...   ...   ...
# 634     6.3     20.1   110   107
# 635     3.7     25.6   104   109
# 636     6.5     20.3    98   102
# 637     5.4     16.0   118   103
# 638     3.2     14.0   105   111
# 639     5.0     16.1   110   104
# 640     2.9     15.5    71   111
# 641     5.0     12.5    92   109
# 642     3.8     24.1   101   107
# 643     4.5     30.2   109   106
# 644     5.2     13.5    84   106
# 645     5.1     17.3   100   100
# 646     2.8     18.7   104   112
# 647     4.2     16.3    99   109
# 648     3.5     22.4   112   109
# 649     3.3     22.6   103   109
# 650     5.4     23.5   102   111
# 651     7.5     11.3    80   103
# 652     5.5     18.2   116   107
# 653     4.5     21.6    99   109
# 654     5.8     19.3   119   106
# 655     5.2     20.8   113   108
# 656     4.5     22.4   105   110
# 657     4.7     18.8    95   110
# 658     5.3     16.9    92   107
# 659     3.7     20.6   107   112
# 660     3.9     24.0   103   114
# 661     4.0     28.4   106   106
# 662     6.3     17.4   108   105
# 663     4.2     19.5    89   112
#
# [664 rows x 65 columns]

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'Status', u'Player', u'Pos', u'Player_ID', u'url', u'G',
#        u'MP', u'PER', u'TS%', u'3PAr', u'FTr', u'ORB%', u'DRB%', u'TRB%',
#        u'AST%', u'STL%', u'BLK%', u'TOV%', u'USG%', u'OBPM', u'DPM', u'BPM',
#        u'FG%', u'AVG_DIST_FGA', u'%FGA_2P', u'%FGA_0-3ft', u'%FGA_3-10ft',
#        u'%FGA_10-16ft', u'%FGA_16ft<3', u'%FGA_3P', u'2P%', u'0-3_FG%',
#        u'3-10_FG%', u'10-16_FG%', u'16<3_FG%', u'3P%', u'%ASTd_2P',
#        u'%FGA_DUNK', u'%ASTd_3P', u'%_CORNER3PA', u'3P%_CORNER3', u'FG_100',
#        u'FGA_100', u'FG%_100', u'3P_100', u'3PA_100', u'3P%_100', u'2P_100',
#        u'2PA_100', u'2P%_100', u'FT_100', u'FTA_100', u'FT%_100', u'ORB_100',
#        u'DRB_100', u'TRB_100', u'AST_100', u'STL_100', u'BLK_100', u'TOV_100',
#        u'PF_100', u'PTS_100', u'ORtg', u'DRtg'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
# Drop unwanted columns
data = data.drop(['Unnamed: 0', 'MP', '3PAr'], axis=1)

# %%
# Filter out players who have played less than 20 games
data = data[data['G']>40]

# %%
data.shape
# Out:
# (547, 62)

# %% [markdown]
# ### Data Preprocessing

# %%
X = data.drop(['Player', 'Pos', 'G', 'Player_ID','url', 'Status'], axis=1)
y = data['Pos']

# %%
# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Dimensionality Reduction with PCA

# %%
pca = PCA(n_components=2)
pca.fit(X_scaled)

X_pca = pca.transform(X_scaled)
print("Cumulative Explained Variance:", pca.explained_variance_ratio_.sum())
# Out:
# ('Cumulative Explained Variance:', 0.544592586464551)

# %% [markdown]
# ### Dimensionality Reduction with LDA, RDA, QDA

# %%
LDA = LinearDiscriminantAnalysis(n_components=2, shrinkage='auto', solver='eigen')

# %%
LDA_reduced_df = LDA.fit(X_scaled,y).transform(X_scaled)
# Out:
# //anaconda/lib/python2.7/site-packages/sklearn/covariance/shrunk_covariance_.py:193: UserWarning: Only one sample available. You may want to reshape your data array
#   warnings.warn("Only one sample available. "
# //anaconda/lib/python2.7/site-packages/sklearn/covariance/empirical_covariance_.py:75: UserWarning: Only one sample available. You may want to reshape your data array
#   warnings.warn("Only one sample available. "

# %%
LDA.score(X_scaled,y)
# Out:
# 0.71846435100548445

# %% [markdown]
# ### Find Best Cluster for KMeans Clustering

# %%
find_best_cluster(LDA_reduced_df,5,20)
# Out:
# best silhouette score: 0.462489210089

# %% [markdown]
# ### KMeans Clustering

# %%
kmeans = kmeans(LDA_reduced_df, 8)

# %%
# Assign labels
data['Cluster'] = kmeans['labels']

# Print silhouette score
print "silhouette score:", kmeans['silhouette_score']
# Out:
# silhouette score: 0.382217871678

# %% [markdown]
# #### Visualize the Scatter Plot

# %%
# Target labels
y = kmeans['labels']
df = pd.DataFrame({'X1':LDA_reduced_df[:,0],'X2':LDA_reduced_df[:,1], 'labels':y})

# # Graph with Seaborn
# sns.set_context("poster", font_scale=1)
# graph = sns.lmplot('X1', 'X2', data=df, fit_reg=False, hue="labels", size=10, palette="deep", markers='s')

# %%
plot_kmeans_cluster(LDA_reduced_df, k_clusters=8, plot_title="""KMeans Clustering on NBA Players in 2014-2017""")

# %% [markdown]
# #### Investigate Clusters

# %%
data.head()
# Out:
#      Status         Player Pos  Player_ID  \
# 0  Inactive     A.J. Price  PG  priceaj01
# 1    Active   Aaron Brooks  PG  brookaa01
# 2    Active   Aaron Gordon  SF  gordoaa01
# 4    Active  Adreian Payne  PF  paynead01
# 5    Active     Al Horford   C  horfoal01
#
#                                                  url    G   PER    TS%    FTr  \
# 0  file:///Users/alexcheng/Downloads/us.sitesucke...  261  12.2  0.486  0.193
# 1  file:///Users/alexcheng/Downloads/us.sitesucke...  594  13.5  0.525  0.201
# 2  file:///Users/alexcheng/Downloads/us.sitesucke...  182  14.3  0.522  0.290
# 4  file:///Users/alexcheng/Downloads/us.sitesucke...   96   7.4  0.444  0.215
# 5  file:///Users/alexcheng/Downloads/us.sitesucke...  623  19.0  0.568  0.216
#
#    ORB%   ...     TRB_100  AST_100  STL_100  BLK_100  TOV_100  PF_100  \
# 0   1.9   ...         4.9      7.4      1.6      0.1      3.0     3.1
# 1   2.1   ...         4.1      7.4      1.4      0.3      3.8     4.6
# 2   7.1   ...        11.2      3.2      1.4      1.2      2.0     4.2
# 4   6.4   ...        11.3      2.4      1.5      0.9      3.3     7.2
# 5   8.0   ...        13.6      4.5      1.3      1.9      2.5     3.7
#
#    PTS_100  ORtg  DRtg  Cluster
# 0     19.8   100   108        6
# 1     24.0   104   110        6
# 2     18.9   107   108        3
# 4     15.1    87   110        3
# 5     22.3   114   104        7
#
# [5 rows x 63 columns]

# %%
mask = (data['Cluster'] == 7)
data[mask][['Player']].head()
# Out:
#                Player
# 5          Al Horford
# 6        Al Jefferson
# 19  Amar'e Stoudemire
# 36      Anthony Davis
# 52      Blake Griffin

# %% [markdown]
# ### Feature Importance for each Cluster

# %%
cluster_data = data[mask].drop(['Player', 'Pos', 'Cluster', 'url', 'Player_ID', 'Status'], axis=1)
league_data = data.drop(['Player', 'Pos', 'Cluster', 'url', 'Player_ID', 'Status'], axis=1)

feature_importance(cluster_data, league_data).reset_index().drop('index', axis=1)
# Out:
#       Feature  Importance  Cluster Average  League Average
# 0  %FGA_0-3ft    0.213455          0.47137        0.335172
# 1   %FGA_DUNK    0.207810          0.14136        0.069234
# 2     2P%_100    0.179113          0.52728        0.485951
# 3         2P%    0.178917          0.52729        0.485967
# 4      PF_100    0.172278          5.82200        4.760512
# 5     FG%_100    0.170443          0.51155        0.454481
# 6         FG%    0.169973          0.51158        0.454477
# 7        ORtg    0.158227        111.68000      106.213894
# 8    %ASTd_2P    0.147013          0.68484        0.537998
# 9         TS%    0.136499          0.55599        0.533362

# %% [markdown]
# ### Cluster Descriptions
# - Cluster 0: Defensive Centers
# - Cluster 1: 3-and-D Wings
# - Cluster 2: Scoring Wings
# - Cluster 3: Versatile Forwards
# - Cluster 4: Floor Generals
# - Cluster 5: Shooting Wings
# - Cluster 6: Combo Guards
# - Cluster 7: Offensive Centers

# %% [markdown]
# ### Save to CSV

# %%
player_list = list(data['Player'])
status_list = list(data['Status'])
playerid_list = list(data['Player_ID'])
url_list = list(data['url'])

# %%
df['Player'] = player_list
df['Status'] = status_list
df['Player_ID'] = playerid_list
df['url'] = url_list
df['labels'] = df['labels'].map({0: 'Defensive Centers',
                                 1: '3-and-D Wings',
                                 2: 'Scoring Wings',
                                 3: 'Versatile Forwards',
                                 4: 'Floor Generals',
                                 5: 'Shooting Wings',
                                 6: 'Combo Guards',
                                 7: 'Offensive Centers'})

df.head()
# Out:
#          X1        X2              labels         Player    Status  Player_ID  \
# 0 -3.721358  0.734826        Combo Guards     A.J. Price  Inactive  priceaj01
# 1 -3.382158  1.127596        Combo Guards   Aaron Brooks    Active  brookaa01
# 2  0.532340 -0.575657  Versatile Forwards   Aaron Gordon    Active  gordoaa01
# 3  1.502679  0.146058  Versatile Forwards  Adreian Payne    Active  paynead01
# 4  2.351004  0.469768   Offensive Centers     Al Horford    Active  horfoal01
#
#                                                  url
# 0  file:///Users/alexcheng/Downloads/us.sitesucke...
# 1  file:///Users/alexcheng/Downloads/us.sitesucke...
# 2  file:///Users/alexcheng/Downloads/us.sitesucke...
# 3  file:///Users/alexcheng/Downloads/us.sitesucke...
# 4  file:///Users/alexcheng/Downloads/us.sitesucke...

# %%
file1_loc = "data/positions_14-17.csv"

df.to_csv(file1_loc)
