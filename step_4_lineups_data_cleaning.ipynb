# %%
import numpy as np
import pandas as pd

# %%
file_loc = "data/best_five_combos/step_1_lineups_14-15.csv"

# %%
df = pd.read_csv(file_loc)
df.head()
# Out:
#     first_pos second_pos  third_pos fourth_pos   fifth_pos TEAM  GP   MIN  \
# 0    M.Barnes  B.Griffin   D.Jordan     C.Paul    J.Redick  LAC  60  1217
# 1   D.Carroll  A.Horford   K.Korver  P.Millsap    J.Teague  ATL  57   915
# 2    H.Barnes    A.Bogut    S.Curry    D.Green  K.Thompson  GSW  58   813
# 3  L.Aldridge    N.Batum  D.Lillard    R.Lopez  W.Matthews  POR  32   629
# 4      B.Beal   M.Gortat  N.Hilario   P.Pierce      J.Wall  WAS  40   596
#
#    OFFRTG  DEFRTG  ...   AST/TO  AST RATIO  OREB%  DREB%  REB%  TO RATIO  \
# 0   117.8   100.0  ...     2.51       21.7   27.1   76.0  52.8       0.1
# 1   109.8   101.6  ...     2.01       21.8   21.2   72.6  47.8       0.2
# 2   114.4    94.8  ...     2.25       22.3   20.3   77.2  50.3       0.1
# 3   107.8    97.1  ...     1.77       16.8   24.9   76.9  52.3       0.1
# 4   106.1    98.7  ...     1.86       20.0   21.6   81.7  51.8       0.1
#
#    EFG%   TS%    PACE   PIE
# 0  57.1  59.5   97.03  60.8
# ...

# %%
player_type = {'A.Abrines': 'Shooting Wings', 'A.Afflalo': 'Shooting Wings','A.Ajinca': 'Defensive Centers',
               'A.Aminu': 'Versatile Forwards','A.Anderson': 'Shooting Wings','A.Bargnani': 'Versatile Forwards',
               'A.Baynes': 'Defensive Centers','A.Bennett': 'Versatile Forwards','A.Bogut': 'Defensive Centers',
               'A.Bradley': 'Shooting Wings','A.Brooks': 'Combo Guards','A.Burks': 'Shooting Wings',
               'A.Crabbe': '3-and-D Wings','A.Davis': 'Offensive Centers','A.Daye': 'Versatile Forwards',
               'A.Drummond': 'Defensive Centers','A.Gee': '3-and-D Wings','A.Goodwin': 'Shooting Wings',
               'A.Gordon': 'Versatile Forwards','A.Goudelock': 'Combo Guards','A.Harrison': 'Combo Guards',
               'A.Horford': 'Offensive Centers','A.Iguodala': 'Shooting Wings','A.Jefferson': 'Offensive Centers',
               'A.Johnson': 'Defensive Centers','A.Kirilenko': 'Versatile Forwards','A.Len': 'Defensive Centers',
               'A.Miller': 'Floor Generals','A.Morrow': 'Shooting Wings','A.Nicholson': 'Versatile Forwards',
               'A.Payne': 'Versatile Forwards', 'A.Price': 'Combo Guards','A.Rivers': 'Scoring Wings',
               'A.Roberson': '3-and-D Wings','A.Shved': 'Scoring Wings','A.Stoudemire': 'Offensive Centers',
               'A.Tolliver': 'Versatile Forwards','A.Varejao': 'Defensive Centers','A.Wiggins': '3-and-D Wings',
               'B.Bass': 'Versatile Forwards','B.Beal': 'Shooting Wings','B.Biyombo': 'Defensive Centers',
               'B.Bogdanovic': '3-and-D Wings','B.Brown': 'Combo Guards','B.Davies': 'Versatile Forwards',
               'B.Diaw': 'Versatile Forwards','B.Gordon': 'Scoring Wings','B.Griffin': 'Offensive Centers',
               'B.Haywood': 'Defensive Centers','B.Hield': 'Shooting Wings','B.Ingram': 'Shooting Wings',
               'B.James': 'Defensive Centers','B.Jennings': 'Combo Guards','B.Knight': 'Scoring Wings',
               'B.Lopez': 'Offensive Centers','B.Marjanovic': 'Defensive Centers','B.McLemore': '3-and-D Wings',
               'B.Portis': 'Offensive Centers','B.Roberts': 'Combo Guards','B.Rush': '3-and-D Wings',
               'B.Udrih': 'Combo Guards','B.Wright': 'Offensive Centers','C.Aldrich': 'Defensive Centers',
               'C.Andersen': 'Defensive Centers', 'C.Anthony': '3-and-D Wings','C.Boozer': 'Offensive Centers',
               'C.Bosh': 'Offensive Centers','C.Brewer': 'Shooting Wings','C.Budinger': '3-and-D Wings',
               'C.Butler': '3-and-D Wings','C.Capela': 'Defensive Centers','C.Copeland': '3-and-D Wings',
               'C.Douglas-Roberts': 'Shooting Wings','C.Early': '3-and-D Wings','C.Felicio': 'Defensive Centers',
               'C.Frye': 'Versatile Forwards','C.Hayes': 'Offensive Centers','C.Jefferson': 'Offensive Centers',
               'C.Johnson': '3-and-D Wings', 'C.Joseph': 'Scoring Wings','C.Kaman': 'Defensive Centers',
               'C.Landry': 'Offensive Centers','C.Lee': 'Shooting Wings','C.Martin': '3-and-D Wings',
               'C.McCollum': 'Scoring Wings','C.Miles': '3-and-D Wings','C.Parsons': '3-and-D Wings',
               'C.Paul': 'Floor Generals','C.Payne': 'Combo Guards','C.Villanueva': 'Versatile Forwards',
               'C.Watson': 'Scoring Wings','C.Wilcox': 'Shooting Wings','C.Zeller': 'Offensive Centers',
               'D.Arthur': 'Offensive Centers','D.Augustin': 'Combo Guards','D.Bertans': 'Versatile Forwards',
               'D.Blair': 'Defensive Centers','D.Booker': 'Shooting Wings','D.Carroll': '3-and-D Wings',
               'D.Collison': 'Combo Guards','D.Cousins': 'Defensive Centers','D.Cunningham': 'Versatile Forwards',
               'D.DeRozan': 'Shooting Wings','D.Dedmon': 'Defensive Centers','D.Exum': 'Scoring Wings',
               'D.Favors': 'Offensive Centers','D.Finney-Smith': '3-and-D Wings','D.Gallinari': '3-and-D Wings',
               'D.Gooden': 'Offensive Centers','D.Granger': '3-and-D Wings','D.Green': 'Versatile Forwards',
               'D.Harris': 'Combo Guards','D.Hilliard': 'Shooting Wings','D.Howard': 'Defensive Centers',
               'D.Jones': 'Shooting Wings','D.Jordan': 'Defensive Centers','D.Lee': 'Offensive Centers',
               'D.Liggins': '3-and-D Wings','D.Lillard': 'Combo Guards','D.Marble': 'Shooting Wings',
               'D.McDermott': '3-and-D Wings','D.Miller': '3-and-D Wings','D.Morris': 'Combo Guards',
               'D.Motiejunas': 'Offensive Centers','D.Nowitzki': 'Versatile Forwards',
               'D.Powell': 'Offensive Centers','D.Rose': 'Combo Guards','D.Rudez': 'Shooting Wings',
               'D.Russell': 'Scoring Wings','D.Sabonis': 'Versatile Forwards','D.Saric': 'Versatile Forwards',
               'D.Schroder': 'Floor Generals','D.Sloan': 'Combo Guards','D.Wade': 'Scoring Wings',
               'D.Waiters': 'Scoring Wings','D.West': 'Offensive Centers','D.Williams': '3-and-D Wings',
               'D.Wright': '3-and-D Wings','E.Barron': 'Offensive Centers','E.Bledsoe': 'Combo Guards',
               'E.Brand': 'Offensive Centers','E.Clark': 'Versatile Forwards','E.Davis': 'Defensive Centers',
               'E.Fournier': 'Shooting Wings','E.Gordon': 'Scoring Wings','E.Green': 'Scoring Wings',
               'E.Ilyasova': 'Offensive Centers','E.Kanter': 'Offensive Centers','E.Millsap': 'Shooting Wings',
               'E.Moore': 'Scoring Wings','E.Mudiay': 'Combo Guards','E.Payton': 'Floor Generals',
               'E.Turner': 'Scoring Wings','E.Udoh': 'Offensive Centers','E.Williams': 'Shooting Wings',
               'F.Aldemir': 'Offensive Centers','F.Ezeli': 'Defensive Centers','F.Garcia': '3-and-D Wings',
               'F.Kaminsky': 'Versatile Forwards','G.Antetokounmpo': 'Versatile Forwards',
               'G.Davis': 'Versatile Forwards','G.Dieng': 'Offensive Centers','G.Dragic': 'Combo Guards',
               'G.Green': 'Shooting Wings','G.Harris': 'Shooting Wings','G.Hayward': 'Shooting Wings',
               'G.Henderson': 'Shooting Wings','G.Hill': 'Scoring Wings','G.Monroe': 'Offensive Centers',
               'G.Neal': 'Shooting Wings','G.Robinson': '3-and-D Wings','G.Smith': 'Defensive Centers',
               'G.Stiemsma': 'Defensive Centers','G.Temple': 'Shooting Wings','G.Vasquez': 'Floor Generals',
               'G.Wallace': '3-and-D Wings','H.Barnes': '3-and-D Wings','H.Sims': 'Offensive Centers',
               'H.Thompson': '3-and-D Wings','H.Turkoglu': 'Shooting Wings','H.Walker': '3-and-D Wings',
               'H.Whiteside': 'Defensive Centers','I.Canaan': 'Scoring Wings','I.Clark': 'Shooting Wings',
               'I.Mahinmi': 'Offensive Centers','I.Shumpert': 'Shooting Wings','I.Smith': 'Floor Generals',
               'I.Thomas': 'Combo Guards','I.Whitehead': 'Scoring Wings','J.Adrien': 'Defensive Centers',
               'J.Anderson': '3-and-D Wings','J.Anthony': 'Offensive Centers','J.Ayres': 'Defensive Centers',
               'J.Barea': 'Combo Guards','J.Bayless': 'Scoring Wings','J.Brown': '3-and-D Wings',
               'J.Butler': 'Shooting Wings','J.Calderon': 'Floor Generals','J.Clarkson': 'Scoring Wings',
               'J.Crawford': 'Scoring Wings','J.Crowder': '3-and-D Wings','J.Cunningham': 'Shooting Wings',
               'J.Dorsey': 'Defensive Centers','J.Dudley': '3-and-D Wings','J.Ennis': '3-and-D Wings',
               'J.Evans': 'Offensive Centers','J.Farmar': 'Combo Guards','J.Fredette': 'Scoring Wings',
               'J.Freeland': 'Defensive Centers','J.Grant': 'Scoring Wings','J.Green': '3-and-D Wings',
               'J.Gutierrez': 'Scoring Wings','J.Hamilton': 'Versatile Forwards','J.Harden': 'Scoring Wings',
               'J.Harris': '3-and-D Wings','J.Henson': 'Defensive Centers','J.Hernangomez': 'Versatile Forwards',
               'J.Hickson': 'Offensive Centers','J.Hill': 'Defensive Centers','J.Holiday': 'Shooting Wings',
               'J.Ingles': 'Shooting Wings','J.Jack': 'Combo Guards','J.Jenkins': 'Shooting Wings',
               'J.Jerebko': 'Versatile Forwards','J.Johnson': 'Scoring Wings','J.Jones': '3-and-D Wings',
               'J.Jordan': 'Defensive Centers','J.Lamb': '3-and-D Wings','J.Lauvergne': 'Offensive Centers',
               'J.Leuer': 'Offensive Centers','J.Lin': 'Combo Guards','J.Lucas III': 'Combo Guards',
               'J.Martin': 'Versatile Forwards','J.Maxiell': 'Offensive Centers','J.McGee': 'Defensive Centers',
               'J.McRae': 'Scoring Wings','J.McRoberts': 'Versatile Forwards','J.Meeks': '3-and-D Wings',
               'J.Michael McAdoo': 'Offensive Centers','J.Murray': 'Shooting Wings','J.Nelson': 'Combo Guards',
               'J.Noah': 'Defensive Centers','J.Nurkic': 'Defensive Centers',"J.O'Bryant": 'Versatile Forwards',
               'J.Okafor': 'Offensive Centers','J.Pargo': 'Combo Guards','J.Parker': '3-and-D Wings',
               'J.Randle': 'Offensive Centers','J.Redick': 'Shooting Wings','J.Richardson': 'Shooting Wings',
               'J.Salmons': 'Scoring Wings','J.Sampson': '3-and-D Wings','J.Simmons': 'Shooting Wings',
               'J.Smith': 'Versatile Forwards','J.Sullinger': 'Offensive Centers','J.Taylor': '3-and-D Wings',
               'J.Teague': 'Floor Generals','J.Terry': 'Scoring Wings','J.Thompson': 'Offensive Centers',
               'J.Valanciunas': 'Defensive Centers','J.Wall': 'Floor Generals','J.Winslow': '3-and-D Wings',
               'J.Withey': 'Defensive Centers','J.Young': 'Combo Guards','K.Anderson': 'Shooting Wings',
               'K.Bazemore': 'Shooting Wings','K.Bryant': 'Shooting Wings','K.Caldwell-Pope': 'Shooting Wings',
               'K.Dunn': 'Combo Guards','K.Durant': '3-and-D Wings','K.Faried': 'Defensive Centers',
               'K.Garnett': 'Offensive Centers','K.Hinrich': 'Combo Guards','K.Humphries': 'Defensive Centers',
               'K.Irving': 'Combo Guards','K.Korver': '3-and-D Wings','K.Koufos': 'Defensive Centers',
               'K.Leonard': '3-and-D Wings','K.Looney': 'Offensive Centers','K.Love': 'Offensive Centers',
               'K.Lowry': 'Combo Guards','K.Marshall': 'Floor Generals','K.Martin': 'Shooting Wings',
               'K.McDaniels': 'Versatile Forwards','K.Middleton': 'Shooting Wings',"K.O'Quinn": 'Defensive Centers',
               'K.Olynyk': 'Versatile Forwards','K.Oubre Jr.': '3-and-D Wings','K.Papanikolaou': 'Shooting Wings',
               'K.Perkins': 'Defensive Centers','K.Porzingis': 'Offensive Centers','K.Seraphin': 'Defensive Centers',
               'K.Singler': '3-and-D Wings','K.Thompson': '3-and-D Wings','K.Towns': 'Defensive Centers',
               'K.Walker': 'Combo Guards','L.Aldridge': 'Offensive Centers','L.Allen': 'Defensive Centers',
               'L.Amundson': 'Defensive Centers','L.Babbitt': '3-and-D Wings','L.Barbosa': 'Shooting Wings',
               'L.Brown': 'Combo Guards','L.Datome': '3-and-D Wings','L.Deng': '3-and-D Wings',
               'L.Fields': '3-and-D Wings','L.Galloway': 'Shooting Wings','L.Hudson': 'Scoring Wings',
               'L.James': 'Scoring Wings','L.Mbah a Moute': 'Versatile Forwards','L.Nance Jr.': 'Versatile Forwards',
               'L.Nogueira': 'Offensive Centers','L.Ridnour': 'Combo Guards','L.Sanders': 'Defensive Centers',
               'L.Scola': 'Offensive Centers','L.Stephenson': 'Scoring Wings','L.Thomas': '3-and-D Wings',
               'L.Williams': 'Scoring Wings','M.Barnes': 'Versatile Forwards','M.Beasley': 'Versatile Forwards',
               'M.Belinelli': 'Shooting Wings','M.Bonner': 'Versatile Forwards','M.Brogdon': 'Combo Guards',
               'M.Brown': 'Shooting Wings','M.Carter-Williams': 'Combo Guards','M.Chalmers': 'Combo Guards',
               'M.Chriss': 'Versatile Forwards','M.Conley': 'Combo Guards','M.Delaney': 'Combo Guards',
               'M.Dellavedova': 'Combo Guards','M.Dunleavy': '3-and-D Wings','M.Ellis': 'Scoring Wings',
               'M.Gasol': 'Offensive Centers','M.Ginobili': 'Scoring Wings','M.Gortat': 'Defensive Centers',
               'M.Harkless': '3-and-D Wings','M.Harrell': 'Offensive Centers','M.Hezonja': 'Shooting Wings',
               'M.Huertas': 'Floor Generals','M.Kidd-Gilchrist': 'Versatile Forwards','M.Kuzminskas': '3-and-D Wings',
               'M.Leonard': 'Offensive Centers','M.McGary': 'Offensive Centers','M.Miller': '3-and-D Wings',
               'M.Morris': 'Versatile Forwards','M.Muscala': 'Offensive Centers','M.Plumlee': 'Offensive Centers',
               'M.Raduljica': 'Defensive Centers','M.Scott': 'Versatile Forwards','M.Smart': 'Scoring Wings',
               'M.Speights': 'Defensive Centers','M.Teletovic': 'Versatile Forwards','M.Thornton': 'Shooting Wings',
               'M.Turner': 'Offensive Centers','M.Webster': '3-and-D Wings','M.Williams': 'Combo Guards',
               'M.World Peace': 'Shooting Wings','N.Batum': '3-and-D Wings','N.Bjelica': 'Versatile Forwards',
               'N.Calathes': 'Combo Guards','N.Cole': 'Combo Guards','N.Collison': 'Offensive Centers',
               'N.Hilario': 'Offensive Centers','N.Jokic': 'Defensive Centers','N.Mirotic': 'Versatile Forwards',
               'N.Mohammed': 'Defensive Centers','N.Noel': 'Offensive Centers','N.Pekovic': 'Defensive Centers',
               'N.Powell': 'Shooting Wings','N.Robinson': 'Scoring Wings','N.Stauskas': 'Shooting Wings',
               'N.Vonleh': 'Offensive Centers','N.Vucevic': 'Defensive Centers','N.Wolters': 'Combo Guards',
               'N.Young': 'Shooting Wings','O.Asik': 'Offensive Centers','O.Casspi': 'Versatile Forwards',
               'O.Johnson': 'Shooting Wings','O.Mayo': 'Shooting Wings','O.Porter Jr.': '3-and-D Wings',
               'P.Antic': 'Versatile Forwards','P.Beverley': 'Scoring Wings','P.Connaughton': '3-and-D Wings',
               'P.Gasol': 'Offensive Centers','P.George': 'Shooting Wings','P.Hairston': '3-and-D Wings',
               'P.Jones': '3-and-D Wings','P.McCaw': 'Shooting Wings','P.Mills': 'Scoring Wings',
               'P.Millsap': 'Offensive Centers','P.Patterson': 'Versatile Forwards','P.Pierce': 'Shooting Wings',
               'P.Pressey': 'Floor Generals','P.Prigioni': 'Combo Guards','P.Siakam': 'Offensive Centers',
               'P.Tucker': '3-and-D Wings','Q.Acy': 'Offensive Centers','Q.Miller': '3-and-D Wings',
               'Q.Pondexter': '3-and-D Wings','R.Anderson': 'Versatile Forwards','R.Bullock': '3-and-D Wings',
               'R.Butler': '3-and-D Wings','R.Covington': '3-and-D Wings','R.Evans': 'Defensive Centers',
               'R.Felton': 'Combo Guards','R.Foye': 'Scoring Wings','R.Gay': '3-and-D Wings',
               'R.Gobert': 'Defensive Centers','R.Hibbert': 'Defensive Centers','R.Hollins': 'Offensive Centers',
               'R.Hollis-Jefferson': 'Versatile Forwards','R.Holmes': 'Offensive Centers',
               'R.Hood': 'Shooting Wings','R.Hummel': 'Versatile Forwards','R.Jackson': 'Combo Guards',
               'R.Jefferson': '3-and-D Wings','R.Kelly': '3-and-D Wings','R.Lopez': 'Defensive Centers',
               'R.McCallum': 'Scoring Wings','R.McGruder': '3-and-D Wings','R.Neto': 'Scoring Wings',
               'R.Price': 'Scoring Wings','R.Rondo': 'Floor Generals','R.Rubio': 'Floor Generals',
               'R.Sacre': 'Offensive Centers','R.Sessions': 'Combo Guards','R.Stuckey': 'Scoring Wings',
               'R.Turiaf': 'Offensive Centers','R.Vaughn': 'Shooting Wings','R.Westbrook': 'Combo Guards',
               'R.Williams': 'Shooting Wings','S.Adams': 'Defensive Centers','S.Blake': 'Combo Guards',
               'S.Brown': 'Shooting Wings','S.Curry': 'Combo Guards','S.Dalembert': 'Defensive Centers',
               'S.Dekker': 'Versatile Forwards','S.Dinwiddie': 'Combo Guards','S.Hawes': 'Offensive Centers',
               'S.Hill': 'Shooting Wings','S.Ibaka': 'Defensive Centers','S.Johnson': 'Shooting Wings',
               'S.Karasev': '3-and-D Wings','S.Kilpatrick': 'Shooting Wings','S.Larkin': 'Combo Guards',
               'S.Livingston': 'Combo Guards','S.Mack': 'Combo Guards','S.Marion': 'Versatile Forwards',
               'S.Mejri': 'Defensive Centers','S.Muhammad': 'Versatile Forwards','S.Napier': 'Combo Guards',
               'S.Novak': '3-and-D Wings','S.Randolph': 'Offensive Centers','S.Rodriguez': 'Floor Generals',
               'S.Telfair': 'Combo Guards','S.Vujacic': 'Shooting Wings','S.Weems': '3-and-D Wings',
               'S.Williams': 'Versatile Forwards','T.Allen': '3-and-D Wings','T.Ariza': '3-and-D Wings',
               'T.Black': 'Defensive Centers','T.Booker': 'Offensive Centers','T.Burke': 'Combo Guards',
               'T.Chandler': 'Defensive Centers','T.Daniels': 'Shooting Wings','T.Douglas': 'Scoring Wings',
               'T.Duncan': 'Defensive Centers','T.Ennis': 'Combo Guards','T.Evans': 'Scoring Wings',
               'T.Frazier': 'Floor Generals','T.Gibson': 'Offensive Centers','T.Hansbrough': 'Offensive Centers',
               'T.Hardaway Jr.': 'Shooting Wings','T.Harris': 'Versatile Forwards','T.Johnson': 'Shooting Wings',
               'T.Jones': 'Floor Generals','T.Lawson': 'Floor Generals','T.Luwawu-Cabarrot': '3-and-D Wings',
               'T.Lyles': 'Versatile Forwards','T.McConnell': 'Floor Generals','T.Mozgov': 'Defensive Centers',
               'T.Murry': 'Scoring Wings','T.Parker': 'Combo Guards','T.Prince': '3-and-D Wings',
               'T.Robinson': 'Offensive Centers','T.Ross': 'Shooting Wings','T.Rozier': 'Scoring Wings',
               'T.Sefolosha': '3-and-D Wings','T.Snell': 'Shooting Wings','T.Splitter': 'Offensive Centers',
               'T.Thomas': 'Offensive Centers','T.Thompson': 'Defensive Centers','T.Warren': '3-and-D Wings',
               'T.Wear': 'Shooting Wings','T.Wroten': 'Scoring Wings','T.Young': 'Versatile Forwards',
               'T.Zeller': 'Defensive Centers','U.Haslem': 'Offensive Centers','V.Carter': 'Shooting Wings',
               'V.Claver': '3-and-D Wings','V.Oladipo': 'Scoring Wings','W.Barton': 'Shooting Wings',
               'W.Bynum': 'Floor Generals','W.Cauley-Stein': 'Offensive Centers','W.Chandler': '3-and-D Wings',
               'W.Ellington': 'Shooting Wings','W.Green': 'Shooting Wings','W.Hernangomez': 'Defensive Centers',
               'W.Johnson': '3-and-D Wings','W.Matthews': 'Shooting Wings','W.Reed': 'Defensive Centers',
               'X.Henry': '3-and-D Wings','Z.LaVine': 'Scoring Wings','Z.Pachulia': 'Offensive Centers',
               'Z.Randolph': 'Offensive Centers'}

# %%
df["position_one"] = df["first_pos"].map(player_type)
df['position_two'] = df['second_pos'].map(player_type)
df['position_three'] = df['third_pos'].map(player_type)
df['position_four'] = df['fourth_pos'].map(player_type)
df['position_five'] = df['fifth_pos'].map(player_type)

# %%
player_type = {
    'Defensive Centers':.001,
    '3-and-D Wings':.01,
    'Scoring Wings':.1,
    'Versatile Forwards':1,
    'Floor Generals':10,
    'Shooting Wings':100,
    'Combo Guards':1000,
    'Offensive Centers':10000
}

# %%
df['position_one'] = df['position_one'].map(player_type)
df['position_two'] = df['position_two'].map(player_type)
df['position_three'] = df['position_three'].map(player_type)
df['position_four'] = df['position_four'].map(player_type)
df['position_five'] = df['position_five'].map(player_type)

# %%
df['unique_id'] = df['position_one'] \
                    + df['position_two'] \
                    + df['position_three'] \
                    + df['position_four'] \
                    + df['position_five']

# %%
df.drop(['first_pos', 'second_pos', 'third_pos', 'fourth_pos','fifth_pos', 
         'position_one', 'position_two', 'position_three','position_four', 
         'position_five', 'TEAM'],
         axis=1, inplace=True)

# %%
df.to_csv('data/best_five_combos/step_2_14-15.csv')
